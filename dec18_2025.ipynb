# %%
ders_no = 4
pi = 3.14159
dersin_ismi = "Python - veri yapıları ve algoritmalar "
durum1 = True
durum2 = False

print(ders_no)
print(pi)
print(dersin_ismi)
print(durum1)
print(durum2)
# Out:
# 4
# 3.14159
# Python - veri yapıları ve algoritmalar
# True
# False

# %%
a = 7
b = 3
print("Toplama" , a+b)
# Out:
# Toplama 10

# %%
a = 7
b = 3
print("Çarpma" , a * b)
print("Üs alma" , a ** b)
print("Mod" , a % b)
# Out:
# Çarpma 21
# Üs alma 343
# Mod 1

# %%
a = 7
b = 3
print("a == b" , a == b)
print("a < b" , a < b)
# Out:
# a == b False
# a < b False

# %%
a = True
b = False
print("a and b:", a and b)
print("a or b:", a or b)
print("not a:", not a)
# Out:
# a and b: False
# a or b: True
# not a: False

# %%
x = 7
x += 3 #x = x + 3
print(x)
# Out:
# 10

# %%
print(7 & 3) # 3
print(7 | 3) # 7
print(7 ^ 3) # 4
print(~3) #-4
print(7 << 3) # 56
# Out:
# 3
# 7
# 4
# -4
# 56

# %% [markdown]
# if yapısı örnekleri

# %%
a = 10
if a > 0:
  a= a + 1
print (a)
# Out:
# 11

# %%
a=5
b=4
c=0
if a>0 and b>0:
  c=a*b+b
print(c)
# Out:
# 24

# %%
a=5
b=4
c=0
if a>0 and b>0:
  c=a+b
  c=a*a+c
print(c)
# Out:
# 34

# %%
a=4
b=1
if a>b:
  print(a)
else:
  print(b)
# Out:
# 4

# %%
a=4
b=1
c=9
sonuc=0
if a>0:
  sonuc +=1
  sonuc=a*c-b
  print(sonuc)
else:
  sonuc-=1
  sonuc=a/c+b
  print(sonuc)
# Out:
# 35

# %% [markdown]
# if elif else

# %%
if ifade1:
  #ifade1 için durum1 işlem blogu
elif ifade2:
  #ifade 2 için durum2 işlem blogu
elif ifade3:
  #ifade 3 için durum3 işlem blogu
else:
  #tüm işlem dışındaki durum4 işlem blogu

# %%
degisken=0
sonuc=0
if degisken ==1:
  sonuc+=1
  print(sonuc)
elif degisken ==2:
  sonuc +=2
  print(sonuc)
elif degisken==3:
  sonuc +=3
  print(sonuc)
else:
  sonuc=0
  print(sonuc)
# Out:
# 0

# %% [markdown]
# for döngüsü

# %%
for i in range(1,11):
  print("sayi-listesi:",i)
# Out:
# sayi-listesi: 1
# sayi-listesi: 2
# sayi-listesi: 3
# sayi-listesi: 4
# sayi-listesi: 5
# sayi-listesi: 6
# sayi-listesi: 7
# sayi-listesi: 8
# sayi-listesi: 9
# sayi-listesi: 10

# %%
for ch in range(ord('A'), ord('Z')+1):
  print('alfabe-listesi:',chr(ch))
# Out:
# alfabe-listesi: A
# alfabe-listesi: B
# alfabe-listesi: C
# alfabe-listesi: D
# alfabe-listesi: E
# alfabe-listesi: F
# alfabe-listesi: G
# alfabe-listesi: H
# alfabe-listesi: I
# alfabe-listesi: J
# alfabe-listesi: K
# alfabe-listesi: L
# alfabe-listesi: M
# alfabe-listesi: N
# alfabe-listesi: O
# alfabe-listesi: P
# alfabe-listesi: Q
# alfabe-listesi: R
# alfabe-listesi: S
# alfabe-listesi: T
# alfabe-listesi: U
# alfabe-listesi: V
# alfabe-listesi: W
# alfabe-listesi: X
# alfabe-listesi: Y
# alfabe-listesi: Z

# %% [markdown]
# while döngüsü

# %%
x=3
c=0
while c<3:
  print('ekran-ciktisi:',c,x)
  x=x*x
  c=c+1
print('dongu-sonu:',c,x)
# Out:
# ekran-ciktisi: 0 3
# ekran-ciktisi: 1 9
# ekran-ciktisi: 2 81
# dongu-sonu: 3 6561

# %%
sayac=4
while sayac * sayac <= 1000:
  print('dongu-sonu',sayac)
  sayac += 1
# Out:
# dongu-sonu 4
# dongu-sonu 5
# dongu-sonu 6
# dongu-sonu 7
# dongu-sonu 8
# dongu-sonu 9
# dongu-sonu 10
# dongu-sonu 11
# dongu-sonu 12
# dongu-sonu 13
# dongu-sonu 14
# dongu-sonu 15
# dongu-sonu 16
# dongu-sonu 17
# dongu-sonu 18
# dongu-sonu 19
# dongu-sonu 20
# dongu-sonu 21
# dongu-sonu 22
# dongu-sonu 23
# dongu-sonu 24
# dongu-sonu 25
# dongu-sonu 26
# dongu-sonu 27
# dongu-sonu 28
# dongu-sonu 29
# dongu-sonu 30
# dongu-sonu 31

# %%
sayi=int(input("bir sayi girin:"))
if sayi%5 ==0:
  print("5'in kuvvetidir")
else:
  print("5'in kuvveti degildir")
# Out:
# bir sayi girin:28
# 5'in kuvveti degildir

# %%
yil= int(input("bir yıl girin:"))
if yil%4 ==0:
  print("artik yildir")
else:
  print("artik yil degildir")
# Out:
# bir yıl girin:2000
# artik yildir

# %%
sayi=1
s=0
toplam=0
while sayi!=0:
  sayi=int(input("bir sayi giriniz(0 ile çıkabilirsiniz):"))
  if sayi!=0:
    toplam+=sayi
    s+=1
if s ==0:
  print("sayi girisi yapmadınız")
else:
  ortalama=toplam/s
  print(s,"tane sayi girilmistir")
  print(toplam)
  print(ortalama)
# Out:
# bir sayi giriniz(0 ile çıkabilirsiniz):31
# bir sayi giriniz(0 ile çıkabilirsiniz):31
# bir sayi giriniz(0 ile çıkabilirsiniz):31
# bir sayi giriniz(0 ile çıkabilirsiniz):0
# 3 tane sayi girilmistir
# 93
# 31.0

# %%
sayilar = [10,20,30,40,50]
toplam=sum(sayilar)
print("toplam", toplam)

print("en büyük sayı", max(sayilar))
print("en küçük sayı", min(sayilar))
# Out:
# toplam 150
# en büyük sayı 50
# en küçük sayı 10

# %%
hafta_gunleri = ("Pazartesi", "Salı", "Çarşamba", "Perşembe", "Cuma", "Cumartesi", "Pazar")

print("Haftanin gunleri:")
for gun in hafta_gunleri:
    print(gun)
# Out:
# Haftanin gunleri:
# Pazartesi
# Salı
# Çarşamba
# Perşembe
# Cuma
# Cumartesi
# Pazar

# %%
# Sözlük veri tipi örneği - 1 Öğrenci Bilgileri

ogrenci = {
    "isim": "Ali",
    "yaş": 25,
    "ders": "Python Programlama",
    "not": 90
}

# Bilgilerin yazdırılması
print("Öğrenci Bilgileri:")
for anahtar, değer in ogrenci.items():
    print(anahtar, değer)
# Out:
# Öğrenci Bilgileri:
# isim Ali
# yaş 25
# ders Python Programlama
# not 90

# %%
# Demet veri tipi örneği - 2) Öğrencilerin adları ve notları bir demette saklanıyor
ogrenciler = (
    ("Ali", (85, 90, 78)),
    ("Ayşe", (88, 76, 92)),
    ("Mehmet", (70, 85, 80)),
    ("Zeynep", (95, 90, 93))
)

# Her öğrencinin ortalama notunu hesaplama
for ogrenci in ogrenciler:
    isim = ogrenci[0]
    notlar = ogrenci[1]
    ortalama = sum(notlar) / len(notlar)
    print(isim, " adlı öğrencinin ortalaması: ", ortalama)
# Out:
# Ali  adlı öğrencinin ortalaması:  84.33333333333333
# Ayşe  adlı öğrencinin ortalaması:  85.33333333333333
# Mehmet  adlı öğrencinin ortalaması:  78.33333333333333
# Zeynep  adlı öğrencinin ortalaması:  92.66666666666667
