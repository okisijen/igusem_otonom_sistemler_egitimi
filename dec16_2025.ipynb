# %% [markdown]
# **16.12.2025 İGÜSEM Otonom Sistemler Eğitimi**
# Yiğit Karakaş

# %%
import sys

# %%
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/otonomsistemler')
# !pwd
# Out:
# /content/drive/My Drive/otonomsistemler
